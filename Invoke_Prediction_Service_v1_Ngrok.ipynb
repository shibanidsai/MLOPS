# %% [markdown]
# <a href="https://colab.research.google.com/github/shibanidsai/MLOPS/blob/main/Invoke_Prediction_Service_v1_Ngrok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Invoking the Prediction Service
#
# **Author:** Manaranjan Pradhan</br>
# **Email ID:** manaranjan@gmail.com</br>
# **LinkedIn:** https://www.linkedin.com/in/manaranjanpradhan/</br>
# **Website:** www.manaranjanp.com
#
#
# ## Prepare the data

# %%
# import requests, json

# %%
import requests

data = {
    "Fuel_Type": "Diesel",
    "Transmission": "Manual",
    "Owner_Type": "First",
    "Age": 8,
    "Model": "ertiga",
    "KM_Driven": 87
}

response = requests.post(
    "https://russ-windswept-undoubtfully.ngrok-free.dev/predict",
    json=data
)

print(response.json())
# Out:
# ['Estimated Car Price: INR 6.0 Lakhs']

# %%
response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# ['Estimated Car Price: INR 6.0 Lakhs']
