# %% [markdown]
# <a href="https://colab.research.google.com/github/shibanidsai/MLOPS/blob/main/Inference_Systems_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib
import pandas as pd

# %%
pipeline=joblib.load("cars.pkl")

# %%
pipeline.named_steps
# Out:
# {'preprocessor': ColumnTransformer(transformers=[('num_imputed',
#                                   Pipeline(steps=[('imputation',
#                                                    SimpleImputer()),
#                                                   ('scaler', StandardScaler())]),
#                                   ['Seats']),
#                                  ('num_not_imputed',
#                                   Pipeline(steps=[('scaler', StandardScaler())]),
#                                   ['age', 'KM_Driven', 'engine', 'power',
#                                    'mileage']),
#                                  ('catvars',
#                                   Pipeline(steps=[('ohencoder',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['Fuel_Type', 'Transmission', 'Owner_Type',
#                                    'make', 'Location'])]),
# ...

# %% [markdown]
# we have features of new car and we will pass it to pkl file

# %%
used_car={"Location":"Bangalore",
          "Fuel_Type"	:"Diesel",
          "Transmission":"Automatic",
          "Owner_Type":"First",
         "Seats":5,
          "age":5,
          "KM_Driven":25,
          "make":"maruti",
          "mileage":20,
          "engine": 1400,
          	"power": 98}

# %%
used_car
# Out:
# {'Location': 'Bangalore',
#  'Fuel_Type': 'Diesel',
#  'Transmission': 'Automatic',
#  'Owner_Type': 'First',
#  'Seats': 5,
#  'age': 5,
#  'KM_Driven': 25,
#  'make': 'maruti',
#  'mileage': 20,
#  'engine': 1400,
#  'power': 98}

# %%
used_car_df=pd.DataFrame(used_car,index=[0])# we encapsulate car data in a dataframe

# %%
pipeline.predict(used_car_df)
# Out:
# array([6.71387132])
